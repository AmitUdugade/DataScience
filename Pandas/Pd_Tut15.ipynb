# %% [markdown]
# <a href="https://colab.research.google.com/github/AmitUdugade/DataScience/blob/main/Pandas/Pd_Tut15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/short_weatherHistory.csv')
df
# Out:
#         Date   Event  Temperature  Humidity  Wind Speed
# 0   4/1/2006    Rain     9.472222      0.89     14.1197
# 1  8/11/2009  Cloudy     9.377778      0.89      3.9284
# 2  6/11/2016     NaN     8.288889      0.83     14.1036
# 3   5/1/2022    Rain     8.755556       NaN     11.0446
# 4  4/18/2015    Rain     9.222222      0.85     13.9587
# 5  8/11/2009  Summer     7.733333      0.95         NaN
# 6  7/21/2018    Snow          NaN      0.89     14.1519

# %%
highest_temp = (df['Temperature']>8)
highest_temp
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# 6    False
# Name: Temperature, dtype: bool

# %%
df.loc[highest_temp]
# Out:
#         Date   Event  Temperature  Humidity  Wind Speed
# 0   4/1/2006    Rain     9.472222      0.89     14.1197
# 1  8/11/2009  Cloudy     9.377778      0.89      3.9284
# 2  6/11/2016     NaN     8.288889      0.83     14.1036
# 3   5/1/2022    Rain     8.755556       NaN     11.0446
# 4  4/18/2015    Rain     9.222222      0.85     13.9587

# %%
df.loc[highest_temp, ['Event','Wind Speed', 'Temperature']]
# Out:
#     Event  Wind Speed  Temperature
# 0    Rain     14.1197     9.472222
# 1  Cloudy      3.9284     9.377778
# 2     NaN     14.1036     8.288889
# 3    Rain     11.0446     8.755556
# 4    Rain     13.9587     9.222222

# %%
df['Event'].unique()
# Out:
# array(['Rain', 'Cloudy', nan, 'Summer', 'Snow'], dtype=object)

# %%
Event_list = ['Rain','Summer','Snow']

filter = df['Event'].isin(Event_list)

df.loc[filter]
# Out:
#         Date   Event  Temperature  Humidity  Wind Speed
# 0   4/1/2006    Rain     9.472222      0.89     14.1197
# 3   5/1/2022    Rain     8.755556       NaN     11.0446
# 4  4/18/2015    Rain     9.222222      0.85     13.9587
# 5  8/11/2009  Summer     7.733333      0.95         NaN
# 6  7/21/2018    Snow          NaN      0.89     14.1519

# %% [markdown]
# #Updating Columns

# %%
df.columns
# Out:
# Index(['Date', 'Event', 'Temperature', 'Humidity', 'Wind Speed'], dtype='object')

# %%
df.columns = df.columns.str.replace(' ','_')

# %%
df.head()
# Out:
#         Date   Event  Temperature  Humidity  Wind_Speed
# 0   4/1/2006    Rain     9.472222      0.89     14.1197
# 1  8/11/2009  Cloudy     9.377778      0.89      3.9284
# 2  6/11/2016     NaN     8.288889      0.83     14.1036
# 3   5/1/2022    Rain     8.755556       NaN     11.0446
# 4  4/18/2015    Rain     9.222222      0.85     13.9587

# %%
df.Wind_Speed
# Out:
# 0    14.1197
# 1     3.9284
# 2    14.1036
# 3    11.0446
# 4    13.9587
# 5        NaN
# 6    14.1519
# Name: Wind_Speed, dtype: float64

# %%
df.rename(columns = {'Wind_Speed' : 'Wind_Speed_renamed'})  #Temporary changed. inplace = True to fix permanent.
# Out:
#         Date   Event  Temperature  Humidity  Wind_Speed_renamed
# 0   4/1/2006    Rain     9.472222      0.89             14.1197
# 1  8/11/2009  Cloudy     9.377778      0.89              3.9284
# 2  6/11/2016     NaN     8.288889      0.83             14.1036
# 3   5/1/2022    Rain     8.755556       NaN             11.0446
# 4  4/18/2015    Rain     9.222222      0.85             13.9587
# 5  8/11/2009  Summer     7.733333      0.95                 NaN
# 6  7/21/2018    Snow          NaN      0.89             14.1519

# %%
df.rename(columns = {'Wind_Speed' : 'Wind_Speed_renamed'}, inplace = True)

# %%
df
# Out:
#         Date   Event  Temperature  Humidity  Wind_Speed_renamed
# 0   4/1/2006    Rain     9.472222      0.89             14.1197
# 1  8/11/2009  Cloudy     9.377778      0.89              3.9284
# 2  6/11/2016     NaN     8.288889      0.83             14.1036
# 3   5/1/2022    Rain     8.755556       NaN             11.0446
# 4  4/18/2015    Rain     9.222222      0.85             13.9587
# 5  8/11/2009  Summer     7.733333      0.95                 NaN
# 6  7/21/2018    Snow          NaN      0.89             14.1519

# %% [markdown]
# # Updating Row

# %%
# Update the Humidity value 0.89	to 0.98 where date  = 08/11/2009

df.loc[1, 'Humidity'] = 0.98
df
# Out:
#         Date   Event  Temperature  Humidity  Wind_Speed_renamed
# 0   4/1/2006    Rain     9.472222      0.89             14.1197
# 1  8/11/2009  Cloudy     9.377778      0.98              3.9284
# 2  6/11/2016     NaN     8.288889      0.83             14.1036
# 3   5/1/2022    Rain     8.755556       NaN             11.0446
# 4  4/18/2015    Rain     9.222222      0.85             13.9587
# 5  8/11/2009  Summer     7.733333      0.95                 NaN
# 6  7/21/2018    Snow          NaN      0.89             14.1519

# %%
#Way 2 - using 'at' attribute. it is faster than 'loc' attribute when it comes to single value

df.at[1, 'Humidity'] = 0.99        #Previously was - df.loc[1, 'Humidity'] = 0.98
df
# Out:
#         Date   Event  Temperature  Humidity  Wind_Speed_renamed
# 0   4/1/2006    Rain     9.472222      0.89             14.1197
# 1  8/11/2009  Cloudy     9.377778      0.99              3.9284
# 2  6/11/2016     NaN     8.288889      0.83             14.1036
# 3   5/1/2022    Rain     8.755556       NaN             11.0446
# 4  4/18/2015    Rain     9.222222      0.85             13.9587
# 5  8/11/2009  Summer     7.733333      0.95                 NaN
# 6  7/21/2018    Snow          NaN      0.89             14.1519

# %% [markdown]
# # Adding and removing columns

# %%
new_column = df['Date'] + df['Event']
new_column
# Out:
# 0       4/1/2006Rain
# 1    8/11/2009Cloudy
# 2                NaN
# 3       5/1/2022Rain
# 4      4/18/2015Rain
# 5    8/11/2009Summer
# 6      7/21/2018Snow
# dtype: object

# %%
df['new_column'] = new_column

# %%
df
# Out:
#         Date   Event  Temperature  Humidity  Wind_Speed_renamed  \
# 0   4/1/2006    Rain     9.472222      0.89             14.1197
# 1  8/11/2009  Cloudy     9.377778      0.99              3.9284
# 2  6/11/2016     NaN     8.288889      0.83             14.1036
# 3   5/1/2022    Rain     8.755556       NaN             11.0446
# 4  4/18/2015    Rain     9.222222      0.85             13.9587
# 5  8/11/2009  Summer     7.733333      0.95                 NaN
# 6  7/21/2018    Snow          NaN      0.89             14.1519
#
#         new_column
# 0     4/1/2006Rain
# 1  8/11/2009Cloudy
# 2              NaN
# 3     5/1/2022Rain
# 4    4/18/2015Rain
# 5  8/11/2009Summer
# 6    7/21/2018Snow

# %%
#Removing particular column

df.drop(columns = ['Humidity'])  #Droping column
# Out:
#         Date   Event  Temperature  Wind_Speed_renamed       new_column
# 0   4/1/2006    Rain     9.472222             14.1197     4/1/2006Rain
# 1  8/11/2009  Cloudy     9.377778              3.9284  8/11/2009Cloudy
# 2  6/11/2016     NaN     8.288889             14.1036              NaN
# 3   5/1/2022    Rain     8.755556             11.0446     5/1/2022Rain
# 4  4/18/2015    Rain     9.222222             13.9587    4/18/2015Rain
# 5  8/11/2009  Summer     7.733333                 NaN  8/11/2009Summer
# 6  7/21/2018    Snow          NaN             14.1519    7/21/2018Snow

# %%
df.drop(index=0)   #Row Drop but temporary.
# Out:
#         Date   Event  Temperature  Humidity  Wind_Speed_renamed  \
# 1  8/11/2009  Cloudy     9.377778      0.99              3.9284
# 2  6/11/2016     NaN     8.288889      0.83             14.1036
# 3   5/1/2022    Rain     8.755556       NaN             11.0446
# 4  4/18/2015    Rain     9.222222      0.85             13.9587
# 5  8/11/2009  Summer     7.733333      0.95                 NaN
# 6  7/21/2018    Snow          NaN      0.89             14.1519
#
#         new_column
# 1  8/11/2009Cloudy
# 2              NaN
# 3     5/1/2022Rain
# 4    4/18/2015Rain
# 5  8/11/2009Summer
# 6    7/21/2018Snow

# %%
df
# Out:
#         Date   Event  Temperature  Humidity  Wind_Speed_renamed  \
# 0   4/1/2006    Rain     9.472222      0.89             14.1197
# 1  8/11/2009  Cloudy     9.377778      0.99              3.9284
# 2  6/11/2016     NaN     8.288889      0.83             14.1036
# 3   5/1/2022    Rain     8.755556       NaN             11.0446
# 4  4/18/2015    Rain     9.222222      0.85             13.9587
# 5  8/11/2009  Summer     7.733333      0.95                 NaN
# 6  7/21/2018    Snow          NaN      0.89             14.1519
#
#         new_column
# 0     4/1/2006Rain
# 1  8/11/2009Cloudy
# 2              NaN
# 3     5/1/2022Rain
# 4    4/18/2015Rain
# 5  8/11/2009Summer
# 6    7/21/2018Snow

# %% [markdown]
# # Sorting data

# %%
df
# Out:
#         Date   Event  Temperature  Humidity  Wind_Speed_renamed  \
# 0   4/1/2006    Rain     9.472222      0.89             14.1197
# 1  8/11/2009  Cloudy     9.377778      0.99              3.9284
# 2  6/11/2016     NaN     8.288889      0.83             14.1036
# 3   5/1/2022    Rain     8.755556       NaN             11.0446
# 4  4/18/2015    Rain     9.222222      0.85             13.9587
# 5  8/11/2009  Summer     7.733333      0.95                 NaN
# 6  7/21/2018    Snow          NaN      0.89             14.1519
#
#         new_column
# 0     4/1/2006Rain
# 1  8/11/2009Cloudy
# 2              NaN
# 3     5/1/2022Rain
# 4    4/18/2015Rain
# 5  8/11/2009Summer
# 6    7/21/2018Snow

# %%
df.sort_values(by='Humidity')
# Out:
#         Date   Event  Temperature  Humidity  Wind_Speed_renamed  \
# 2  6/11/2016     NaN     8.288889      0.83             14.1036
# 4  4/18/2015    Rain     9.222222      0.85             13.9587
# 0   4/1/2006    Rain     9.472222      0.89             14.1197
# 6  7/21/2018    Snow          NaN      0.89             14.1519
# 5  8/11/2009  Summer     7.733333      0.95                 NaN
# 1  8/11/2009  Cloudy     9.377778      0.99              3.9284
# 3   5/1/2022    Rain     8.755556       NaN             11.0446
#
#         new_column
# 2              NaN
# 4    4/18/2015Rain
# 0     4/1/2006Rain
# 6    7/21/2018Snow
# 5  8/11/2009Summer
# 1  8/11/2009Cloudy
# 3     5/1/2022Rain

# %%
df.sort_values(by='Humidity', ascending=False)
# Out:
#         Date   Event  Temperature  Humidity  Wind_Speed_renamed  \
# 1  8/11/2009  Cloudy     9.377778      0.99              3.9284
# 5  8/11/2009  Summer     7.733333      0.95                 NaN
# 0   4/1/2006    Rain     9.472222      0.89             14.1197
# 6  7/21/2018    Snow          NaN      0.89             14.1519
# 4  4/18/2015    Rain     9.222222      0.85             13.9587
# 2  6/11/2016     NaN     8.288889      0.83             14.1036
# 3   5/1/2022    Rain     8.755556       NaN             11.0446
#
#         new_column
# 1  8/11/2009Cloudy
# 5  8/11/2009Summer
# 0     4/1/2006Rain
# 6    7/21/2018Snow
# 4    4/18/2015Rain
# 2              NaN
# 3     5/1/2022Rain

# %%
df.sort_index(ascending = False)
# Out:
#         Date   Event  Temperature  Humidity  Wind_Speed_renamed  \
# 6  7/21/2018    Snow          NaN      0.89             14.1519
# 5  8/11/2009  Summer     7.733333      0.95                 NaN
# 4  4/18/2015    Rain     9.222222      0.85             13.9587
# 3   5/1/2022    Rain     8.755556       NaN             11.0446
# 2  6/11/2016     NaN     8.288889      0.83             14.1036
# 1  8/11/2009  Cloudy     9.377778      0.99              3.9284
# 0   4/1/2006    Rain     9.472222      0.89             14.1197
#
#         new_column
# 6    7/21/2018Snow
# 5  8/11/2009Summer
# 4    4/18/2015Rain
# 3     5/1/2022Rain
# 2              NaN
# 1  8/11/2009Cloudy
# 0     4/1/2006Rain

# %%
df['Event'].sort_values()
# Out:
# 1    Cloudy
# 0      Rain
# 3      Rain
# 4      Rain
# 6      Snow
# 5    Summer
# 2       NaN
# Name: Event, dtype: object

# %% [markdown]
# # Clean & Save Data

# %%
df.isnull().sum()
# Out:
# Date                  0
# Event                 1
# Temperature           1
# Humidity              1
# Wind_Speed_renamed    1
# new_column            1
# dtype: int64

# %%
df.isnull()
# Out:
#     Date  Event  Temperature  Humidity  Wind_Speed_renamed  new_column
# 0  False  False        False     False               False       False
# 1  False  False        False     False               False       False
# 2  False   True        False     False               False        True
# 3  False  False        False      True               False       False
# 4  False  False        False     False               False       False
# 5  False  False        False     False                True       False
# 6  False  False         True     False               False       False

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#         Date   Event  Temperature  Humidity  Wind_Speed_renamed  \
# 0   4/1/2006    Rain     9.472222      0.89             14.1197
# 1  8/11/2009  Cloudy     9.377778      0.99              3.9284
# 4  4/18/2015    Rain     9.222222      0.85             13.9587
#
#         new_column
# 0     4/1/2006Rain
# 1  8/11/2009Cloudy
# 4    4/18/2015Rain

# %%
df.isnull().sum()
# Out:
# Date                  0
# Event                 0
# Temperature           0
# Humidity              0
# Wind_Speed_renamed    0
# new_column            0
# dtype: int64

# %%
df.to_csv('new_whether_udemy.csv')   #It will create a new csv file to the local directory.
