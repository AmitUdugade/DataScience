# %% [markdown]
# <a href="https://colab.research.google.com/github/AmitUdugade/DataScience/blob/main/Pandas/Pd_Tut13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Stack unstack

import pandas as pd

df = pd.read_excel("/content/stock2_data.xlsx", header=[0,1])
df
# Out:
#        Price                            Price to Earning Ratio (P/E)          \
#      company facebook google  microsoft                     facebook google
# 0 2019-05-06      155     850       256                        37.10   32.00
# 1 2019-05-07      156     874       255                        36.98   36.00
# 2 2019-05-08      155     899       214                        36.98   35.44
# 3 2019-05-09      154     855       230                        36.11   38.10
# 4 2019-05-10      168     861       238                        35.99   37.22
#
#
#   microsoft
# 0     30.11
# 1     31.00
# 2     30.22
# 3     31.55
# 4     32.10

# %%
df_stacked = df.stack(level=0)

# %%
# unstack -

df_stacked.unstack()
# Out:
#      company                              facebook  \
#        Price Price to Earning Ratio (P/E)    Price
# 0 2019-05-06                          NaT    155.0
# 1 2019-05-07                          NaT    156.0
# 2 2019-05-08                          NaT    155.0
# 3 2019-05-09                          NaT    154.0
# 4 2019-05-10                          NaT    168.0
#
#                                google                               microsoft  \
#   Price to Earning Ratio (P/E)   Price Price to Earning Ratio (P/E)     Price
# 0                        37.10   850.0                        32.00     256.0
# 1                        36.98   874.0                        36.00     255.0
# 2                        36.98   899.0                        35.44     214.0
# 3                        36.11   855.0                        38.10     230.0
# 4                        35.99   861.0                        37.22     238.0
#
#
#   Price to Earning Ratio (P/E)
# ...
