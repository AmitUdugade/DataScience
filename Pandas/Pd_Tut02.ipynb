# %% [markdown]
# <a href="https://colab.research.google.com/github/AmitUdugade/DataScience/blob/main/Pandas/Pd_Tut02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Dataframe is the main object in pandas.
# It is used to represent the data with rows and columns.
# (Tubular or excel spreadsheet like data)

import pandas as pd

df = pd.read_csv('/content/short_weatherHistory.csv')
df
# Out:
#                    Formatted Date        Summary Precip Type  Temperature (C)  \
# 0   2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1   2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2   2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3   2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4   2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
# 5   2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain         9.222222
# 6   2006-04-01 06:00:00.000 +0200  Partly Cloudy        rain         7.733333
# 7   2006-04-01 07:00:00.000 +0200  Partly Cloudy        rain         8.772222
# 8   2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain        10.822222
# 9   2006-04-01 09:00:00.000 +0200  Partly Cloudy        rain        13.772222
# 10  2006-04-01 10:00:00.000 +0200  Partly Cloudy        rain        16.016667
# ...

# %%
rows, columns = df.shape

# %%
rows
# Out:
# 13

# %%
columns
# Out:
# 12

# %%
df.tail(2)
# Out:
#                    Formatted Date        Summary Precip Type  Temperature (C)  \
# 11  2006-04-01 11:00:00.000 +0200  Partly Cloudy        rain        17.144444
# 12  2006-04-01 12:00:00.000 +0200  Partly Cloudy        rain        17.800000
#
#     Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 11                 17.144444      0.54                NaN
# 12                 17.800000      0.55            21.9443
#
#     Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 11                     316          11.4471           0               1017.74
# 12                     281          11.2700           0               1017.59
#
#                         Daily Summary
# 11  Partly cloudy throughout the day.
# 12  Partly cloudy throughout the day.

# %%
df[2:10]
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
# 5  2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain         9.222222
# 6  2006-04-01 06:00:00.000 +0200  Partly Cloudy        rain         7.733333
# 7  2006-04-01 07:00:00.000 +0200  Partly Cloudy        rain         8.772222
# 8  2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain        10.822222
# 9  2006-04-01 09:00:00.000 +0200  Partly Cloudy        rain        13.772222
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
# ...

# %%
df[:]     #to print all the records.
# Out:
#                    Formatted Date        Summary Precip Type  Temperature (C)  \
# 0   2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1   2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2   2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3   2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4   2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
# 5   2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain         9.222222
# 6   2006-04-01 06:00:00.000 +0200  Partly Cloudy        rain         7.733333
# 7   2006-04-01 07:00:00.000 +0200  Partly Cloudy        rain         8.772222
# 8   2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain        10.822222
# 9   2006-04-01 09:00:00.000 +0200  Partly Cloudy        rain        13.772222
# 10  2006-04-01 10:00:00.000 +0200  Partly Cloudy        rain        16.016667
# ...

# %%
df.columns   #all the columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
df['Summary']
# Out:
# 0     Partly Cloudy
# 1     Partly Cloudy
# 2     Mostly Cloudy
# 3     Partly Cloudy
# 4     Mostly Cloudy
# 5     Partly Cloudy
# 6     Partly Cloudy
# 7     Partly Cloudy
# 8     Partly Cloudy
# 9     Partly Cloudy
# 10    Partly Cloudy
# 11    Partly Cloudy
# 12    Partly Cloudy
# Name: Summary, dtype: object

# %%
type(df['Pressure (millibars)'])
# Out:
# pandas.core.series.Series

# %%
df[['Formatted Date','Wind Speed (km/h)','Temperature (C)']]
# Out:
#                    Formatted Date  Wind Speed (km/h)  Temperature (C)
# 0   2006-04-01 00:00:00.000 +0200            14.1197         9.472222
# 1   2006-04-01 01:00:00.000 +0200            14.2646         9.355556
# 2   2006-04-01 02:00:00.000 +0200             3.9284         9.377778
# 3   2006-04-01 03:00:00.000 +0200            14.1036         8.288889
# 4   2006-04-01 04:00:00.000 +0200            11.0446         8.755556
# 5   2006-04-01 05:00:00.000 +0200            13.9587         9.222222
# 6   2006-04-01 06:00:00.000 +0200                NaN         7.733333
# 7   2006-04-01 07:00:00.000 +0200            14.1519         8.772222
# 8   2006-04-01 08:00:00.000 +0200            11.3183        10.822222
# 9   2006-04-01 09:00:00.000 +0200            12.5258        13.772222
# 10  2006-04-01 10:00:00.000 +0200            17.5651        16.016667
# 11  2006-04-01 11:00:00.000 +0200                NaN        17.144444
# ...

# %%
df.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)   Humidity  \
# count        13.000000                 13.000000  13.000000
# mean         11.271795                 10.125641   0.791538
# std           3.591306                  4.506551   0.131520
# min           7.733333                  5.522222   0.540000
# 25%           8.772222                  6.977778   0.720000
# 50%           9.377778                  7.388889   0.830000
# 75%          13.772222                 13.772222   0.890000
# max          17.800000                 17.800000   0.950000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count          11.000000               13.000000        13.000000        13.0
# mean           13.538636              264.923077        12.851515         0.0
# std             4.394731               25.542323         2.651756         0.0
# min             3.928400              204.000000         9.982000         0.0
# ...

# %%
df.describe().T
# Out:
#                           count         mean        std          min  \
# Temperature (C)            13.0    11.271795   3.591306     7.733333
# Apparent Temperature (C)   13.0    10.125641   4.506551     5.522222
# Humidity                   13.0     0.791538   0.131520     0.540000
# Wind Speed (km/h)          11.0    13.538636   4.394731     3.928400
# Wind Bearing (degrees)     13.0   264.923077  25.542323   204.000000
# Visibility (km)            13.0    12.851515   2.651756     9.982000
# Loud Cover                 13.0     0.000000   0.000000     0.000000
# Pressure (millibars)       13.0  1016.706154   0.787406  1015.130000
#
#                                   25%          50%          75%        max
# Temperature (C)              8.772222     9.377778    13.772222    17.8000
# Apparent Temperature (C)     6.977778     7.388889    13.772222    17.8000
# Humidity                     0.720000     0.830000     0.890000     0.9500
# ...

# %%
df[df.Temperature (C)>= 10]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-be38538d97dd> in <cell line: 2>()
#       1 df = pd.read_csv('/content/short_weatherHistory.csv')
# ----> 2 df[df.Temperature (C)>= 10]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Temperature'

# %%
df[df['Temperature (C)'] >= 10]
# Out:
#                    Formatted Date        Summary Precip Type  Temperature (C)  \
# 8   2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain        10.822222
# 9   2006-04-01 09:00:00.000 +0200  Partly Cloudy        rain        13.772222
# 10  2006-04-01 10:00:00.000 +0200  Partly Cloudy        rain        16.016667
# 11  2006-04-01 11:00:00.000 +0200  Partly Cloudy        rain        17.144444
# 12  2006-04-01 12:00:00.000 +0200  Partly Cloudy        rain        17.800000
#
#     Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 8                  10.822222      0.82            11.3183
# 9                  13.772222      0.72            12.5258
# 10                 16.016667      0.67            17.5651
# 11                 17.144444      0.54                NaN
# 12                 17.800000      0.55            21.9443
#
#     Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# ...

# %%
df[['Formatted Date','Temperature (C)']]
# Out:
#                    Formatted Date  Temperature (C)
# 0   2006-04-01 00:00:00.000 +0200         9.472222
# 1   2006-04-01 01:00:00.000 +0200         9.355556
# 2   2006-04-01 02:00:00.000 +0200         9.377778
# 3   2006-04-01 03:00:00.000 +0200         8.288889
# 4   2006-04-01 04:00:00.000 +0200         8.755556
# 5   2006-04-01 05:00:00.000 +0200         9.222222
# 6   2006-04-01 06:00:00.000 +0200         7.733333
# 7   2006-04-01 07:00:00.000 +0200         8.772222
# 8   2006-04-01 08:00:00.000 +0200        10.822222
# 9   2006-04-01 09:00:00.000 +0200        13.772222
# 10  2006-04-01 10:00:00.000 +0200        16.016667
# 11  2006-04-01 11:00:00.000 +0200        17.144444
# 12  2006-04-01 12:00:00.000 +0200        17.800000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=13, step=1)

# %%
 df.set_index('Formatted Date', inplace=True)

# %%
df
# Out:
#                                      Summary Precip Type  Temperature (C)  \
# Formatted Date
# 2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
# 2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain         9.222222
# 2006-04-01 06:00:00.000 +0200  Partly Cloudy        rain         7.733333
# 2006-04-01 07:00:00.000 +0200  Partly Cloudy        rain         8.772222
# 2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain        10.822222
# 2006-04-01 09:00:00.000 +0200  Partly Cloudy        rain        13.772222
# 2006-04-01 10:00:00.000 +0200  Partly Cloudy        rain        16.016667
# ...

# %%
df.loc['2006-04-01 12:00:00.000 +0200']
# Out:
# Summary                                         Partly Cloudy
# Precip Type                                              rain
# Temperature (C)                                          17.8
# Apparent Temperature (C)                                 17.8
# Humidity                                                 0.55
# Wind Speed (km/h)                                     21.9443
# Wind Bearing (degrees)                                    281
# Visibility (km)                                         11.27
# Loud Cover                                                  0
# Pressure (millibars)                                  1017.59
# Daily Summary               Partly cloudy throughout the day.
# Name: 2006-04-01 12:00:00.000 +0200, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                    Formatted Date        Summary Precip Type  Temperature (C)  \
# 0   2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1   2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2   2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3   2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4   2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
# 5   2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain         9.222222
# 6   2006-04-01 06:00:00.000 +0200  Partly Cloudy        rain         7.733333
# 7   2006-04-01 07:00:00.000 +0200  Partly Cloudy        rain         8.772222
# 8   2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain        10.822222
# 9   2006-04-01 09:00:00.000 +0200  Partly Cloudy        rain        13.772222
# 10  2006-04-01 10:00:00.000 +0200  Partly Cloudy        rain        16.016667
# ...
