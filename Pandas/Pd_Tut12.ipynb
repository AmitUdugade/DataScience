# %% [markdown]
# <a href="https://colab.research.google.com/github/AmitUdugade/DataScience/blob/main/Pandas/Pd_Tut12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# melt - melt is used to transform or reshape the data.

import pandas as pd

df = pd.read_csv("/content/whether3.csv")
df
# Out:
#          day  mumbai  hydrabad  gujrat
# 0     Monday      32        34      35
# 1    Tuesday      35        35      34
# 2  Wednesday      29        36      30
# 3   Thursday      34        32      32
# 4     Friday      32        31      31
# 5   Saturday      31        30      34
# 6     Sunday      30        35      36

# %%
df1 = pd.melt(df, id_vars = ['day'])
df1
# Out:
#           day  variable  value
# 0      Monday    mumbai     32
# 1     Tuesday    mumbai     35
# 2   Wednesday    mumbai     29
# 3    Thursday    mumbai     34
# 4      Friday    mumbai     32
# 5    Saturday    mumbai     31
# 6      Sunday    mumbai     30
# 7      Monday  hydrabad     34
# 8     Tuesday  hydrabad     35
# 9   Wednesday  hydrabad     36
# 10   Thursday  hydrabad     32
# 11     Friday  hydrabad     31
# 12   Saturday  hydrabad     30
# 13     Sunday  hydrabad     35
# 14     Monday    gujrat     35
# 15    Tuesday    gujrat     34
# 16  Wednesday    gujrat     30
# 17   Thursday    gujrat     32
# 18     Friday    gujrat     31
# 19   Saturday    gujrat     34
# 20     Sunday    gujrat     36

# %%
#Fetch particular city
df1[df1['variable']=='mumbai']
# Out:
#          day variable  value
# 0     Monday   mumbai     32
# 1    Tuesday   mumbai     35
# 2  Wednesday   mumbai     29
# 3   Thursday   mumbai     34
# 4     Friday   mumbai     32
# 5   Saturday   mumbai     31
# 6     Sunday   mumbai     30

# %%
df1 = pd.melt(df, id_vars = ['day'], var_name="city", value_name="temperature")
df1
# Out:
#           day      city  temperature
# 0      Monday    mumbai           32
# 1     Tuesday    mumbai           35
# 2   Wednesday    mumbai           29
# 3    Thursday    mumbai           34
# 4      Friday    mumbai           32
# 5    Saturday    mumbai           31
# 6      Sunday    mumbai           30
# 7      Monday  hydrabad           34
# 8     Tuesday  hydrabad           35
# 9   Wednesday  hydrabad           36
# 10   Thursday  hydrabad           32
# 11     Friday  hydrabad           31
# 12   Saturday  hydrabad           30
# 13     Sunday  hydrabad           35
# 14     Monday    gujrat           35
# 15    Tuesday    gujrat           34
# 16  Wednesday    gujrat           30
# 17   Thursday    gujrat           32
# 18     Friday    gujrat           31
# 19   Saturday    gujrat           34
# 20     Sunday    gujrat           36
